# %%
import pandas as pd
import matplotlib.pyplot as pt

# %%
data = pd.read_csv("dataseto/sets.csv")

# %%
data.head(15)
# Out:
#    set_num                               name    year  theme_id  num_parts
# 0     00-1                    Weetabix Castle  1970.0     414.0      414.0
# 1   0011-2                  Town Mini-Figures  1978.0       NaN      414.0
# 2   0011-2                  Town Mini-Figures  1978.0       NaN      414.0
# 3   0012-1                 Space Mini-Figures  1979.0     143.0       12.0
# 4   0013-1                 Space Mini-Figures     NaN     143.0       12.0
# 5   0014-1                 Space Mini-Figures  1979.0     143.0       12.0
# 6   0015-1                 Space Mini-Figures  1979.0     143.0       18.0
# 7   0016-1                                NaN  1978.0     186.0       15.0
# 8     00-2       Weetabix Promotional House 1  1976.0     413.0      147.0
# 9     00-3       Weetabix Promotional House 2  1976.0     413.0      149.0
# 10    00-4      Weetabix Promotional Windmill  1976.0     413.0      126.0
# ...

# %%
data.tail(10)
# Out:
#              set_num                                               name  \
# 11663     VPorient-1  Orient Expedition Value Pack with LEGO Backpac...
# 11664        vwkit-1                                     Volkswagen Kit
# 11665         W098-1                            Watch Set, Classic Blue
# 11666      W991526-1  Homeschool Introduction to Simple and Motorize...
# 11667      Watford-1  LEGO Store Grand Opening Exclusive Set, Watfor...
# 11668    Wauwatosa-1  LEGO Store Grand Opening Exclusive Set, Mayfai...
# 11669   WHITEHOUSE-1                                  Micro White House
# 11670    Wiesbaden-1  LEGO Store Grand Opening Exclusive Set, Wiesba...
# 11671  WishingWell-1                     Wishing Well [Toys R Us Promo]
# 11672        wwgp1-1                Wild West Limited Edition Gift Pack
#
#          year  theme_id  num_parts
# 11663  2003.0     300.0        4.0
# 11664  1959.0     366.0       22.0
# 11665  2006.0     501.0        0.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11673 entries, 0 to 11672
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   set_num    11673 non-null  object
#  1   name       11672 non-null  object
#  2   year       11671 non-null  float64
#  3   theme_id   11669 non-null  float64
#  4   num_parts  11672 non-null  float64
# dtypes: float64(3), object(2)
# memory usage: 456.1+ KB

# %%
data.describe()
# Out:
#                year      theme_id     num_parts
# count  11671.000000  11669.000000  11672.000000
# mean    2001.973781    311.351101    162.340045
# std       13.475943    178.011161    330.209391
# min     1950.000000      1.000000     -1.000000
# 25%     1997.000000    161.000000     10.000000
# 50%     2005.000000    324.000000     45.000000
# 75%     2012.000000    470.000000    172.000000
# max     2017.000000    614.000000   5922.000000

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 11668    False
# 11669    False
# 11670    False
# 11671    False
# 11672    False
# Length: 11673, dtype: bool

# %%
data = data.drop_duplicates()
data
# Out:
#              set_num                                               name  \
# 0               00-1                                    Weetabix Castle
# 1             0011-2                                  Town Mini-Figures
# 3             0012-1                                 Space Mini-Figures
# 4             0013-1                                 Space Mini-Figures
# 5             0014-1                                 Space Mini-Figures
# ...              ...                                                ...
# 11668    Wauwatosa-1  LEGO Store Grand Opening Exclusive Set, Mayfai...
# 11669   WHITEHOUSE-1                                  Micro White House
# 11670    Wiesbaden-1  LEGO Store Grand Opening Exclusive Set, Wiesba...
# 11671  WishingWell-1                     Wishing Well [Toys R Us Promo]
# 11672        wwgp1-1                Wild West Limited Edition Gift Pack
#
#          year  theme_id  num_parts
# 0      1970.0     414.0      414.0
# ...

# %%
data.isnull().sum()
# Out:
# set_num      0
# name         1
# year         2
# theme_id     3
# num_parts    1
# dtype: int64

# %%
data.dropna()
# Out:
#              set_num                                               name  \
# 0               00-1                                    Weetabix Castle
# 3             0012-1                                 Space Mini-Figures
# 5             0014-1                                 Space Mini-Figures
# 6             0015-1                                 Space Mini-Figures
# 8               00-2                       Weetabix Promotional House 1
# ...              ...                                                ...
# 11668    Wauwatosa-1  LEGO Store Grand Opening Exclusive Set, Mayfai...
# 11669   WHITEHOUSE-1                                  Micro White House
# 11670    Wiesbaden-1  LEGO Store Grand Opening Exclusive Set, Wiesba...
# 11671  WishingWell-1                     Wishing Well [Toys R Us Promo]
# 11672        wwgp1-1                Wild West Limited Edition Gift Pack
#
#          year  theme_id  num_parts
# 0      1970.0     414.0      414.0
# ...

# %%
data = data.fillna(0)
data
# Out:
#              set_num                                               name  \
# 0               00-1                                    Weetabix Castle
# 1             0011-2                                  Town Mini-Figures
# 3             0012-1                                 Space Mini-Figures
# 4             0013-1                                 Space Mini-Figures
# 5             0014-1                                 Space Mini-Figures
# ...              ...                                                ...
# 11668    Wauwatosa-1  LEGO Store Grand Opening Exclusive Set, Mayfai...
# 11669   WHITEHOUSE-1                                  Micro White House
# 11670    Wiesbaden-1  LEGO Store Grand Opening Exclusive Set, Wiesba...
# 11671  WishingWell-1                     Wishing Well [Toys R Us Promo]
# 11672        wwgp1-1                Wild West Limited Edition Gift Pack
#
#          year  theme_id  num_parts
# 0      1970.0     414.0      414.0
# ...

# %%
data.boxplot()
# Out:
# <AxesSubplot: >

# %%
data.to_csv("dataseto/output.csv",index=False)
